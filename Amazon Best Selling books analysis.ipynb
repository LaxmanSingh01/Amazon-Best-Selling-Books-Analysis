# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Data Exploration

# %%
data=pd.read_csv('bestsellers with categories.csv')

# %%
data.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
data.shape
# Out:
# (550, 7)

# %%
data.isnull().sum()
# Out:
# Name           0
# Author         0
# User Rating    0
# Reviews        0
# Price          0
# Year           0
# Genre          0
# dtype: int64

# %%
sns.heatmap(data.isnull().sum().to_frame(),annot=True,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Data Preperation

# %%
data.rename(columns={"User Rating": "User_Rating"}, inplace=True)
data[data.Author == 'J. K. Rowling']
data[data.Author == 'J.K. Rowling']
data.loc[data.Author == 'J. K. Rowling', 'Author'] = 'J.K. Rowling'
data['name_len'] = data['Name'].apply(lambda x: len(x) - x.count(" ")) # subtract whitespaces

# %%
data['Genre'].value_counts()
# Out:
# Non Fiction    310
# Fiction        240
# Name: Genre, dtype: int64

# %%
# Pie chart
labels = ['Non Fiction', 'Fiction']
#colors
colors = ['#ff9999','#66b3ff']
 
fig1, ax1 = plt.subplots(figsize=(12,6))
ax1.pie(data['Genre'].value_counts(), colors = colors, labels=labels, autopct='%1.1f%%', startangle=90,shadow=True)
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.title('Distribution of Genre of all the books from 2009 to 2019',fontsize=18)
plt.show()

# %% [markdown]
# #### we can see that Non fiction sale of book is more than fiction books

# %% [markdown]
# ## Now let’s visualize the above insights according to each year:

# %%
fig, ax = plt.subplots(2, 6, figsize=(12,6))
ax[0,0].pie(x=data[data['Year']==2009]['Genre'].value_counts(), labels=None, autopct='%1.1f%%',
            startangle=90, textprops={'size': 12, 'color': 'white'},
            pctdistance=0.5, radius=1.3, colors=['#ff9999','#66b3ff'])
ax[0,0].set_title(2009)
ax[0,1].pie(x=data[data['Year']==2010]['Genre'].value_counts(), labels=None, autopct='%1.1f%%',
            startangle=90, textprops={'size': 12, 'color': 'white'},
            pctdistance=0.5, radius=1.3, colors=['#ff9999','#66b3ff'])
ax[0,1].set_title(2010)
ax[0,2].pie(x=data[data['Year']==2011]['Genre'].value_counts(), labels=None, autopct='%1.1f%%',
            startangle=90, textprops={'size': 12, 'color': 'white'},
            pctdistance=0.5, radius=1.3, colors=['#ff9999','#66b3ff'])
ax[0,2].set_title(2011)
ax[0,3].pie(x=data[data['Year']==2012]['Genre'].value_counts(), labels=None, autopct='%1.1f%%',
            startangle=90, textprops={'size': 12, 'color': 'white'},
            pctdistance=0.5, radius=1.3, colors=['#ff9999','#66b3ff'])
ax[0,3].set_title(2012)
ax[0,4].pie(x=data[data['Year']==2013]['Genre'].value_counts(), labels=None, autopct='%1.1f%%',
            startangle=90, textprops={'size': 12, 'color': 'white'},
            pctdistance=0.5, radius=1.3, colors=['#ff9999','#66b3ff'])
ax[0,4].set_title(2013)
ax[0,5].pie(x=data[data['Year']==2014]['Genre'].value_counts(), labels=None, autopct='%1.1f%%',
            startangle=90, textprops={'size': 12, 'color': 'white'},
            pctdistance=0.5, radius=1.3, colors=['#ff9999','#66b3ff'])
ax[0,5].set_title(2014)
ax[1,0].pie(x=data[data['Year']==2015]['Genre'].value_counts(), labels=None, autopct='%1.1f%%',
            startangle=90, textprops={'size': 12, 'color': 'white'},
            pctdistance=0.5, radius=1.3, colors=['#ff9999','#66b3ff'])
ax[1,0].set_title(2015)
ax[1,1].pie(x=data[data['Year']==2016]['Genre'].value_counts(), labels=None, autopct='%1.1f%%',
            startangle=90, textprops={'size': 12, 'color': 'white'},
            pctdistance=0.5, radius=1.3, colors=['#ff9999','#66b3ff'])
ax[1,1].set_title(2016)
ax[1,2].pie(x=data[data['Year']==2017]['Genre'].value_counts(), labels=None, autopct='%1.1f%%',
            startangle=90, textprops={'size': 12, 'color': 'white'},
            pctdistance=0.5, radius=1.3, colors=['#ff9999','#66b3ff'])
ax[1,2].set_title(2017)
ax[1,3].pie(x=data[data['Year']==2018]['Genre'].value_counts(), labels=None, autopct='%1.1f%%',
            startangle=90, textprops={'size': 12, 'color': 'white'},
            pctdistance=0.5, radius=1.3, colors=['#ff9999','#66b3ff'])
ax[1,3].set_title(2018)
ax[1,4].pie(x=data[data['Year']==2019]['Genre'].value_counts(), labels=None, autopct='%1.1f%%',
            startangle=90, textprops={'size': 12, 'color': 'white'},
            pctdistance=0.5, radius=1.3, colors=['#ff9999','#66b3ff'])
ax[1,4].set_title(2019)
ax[1,5].pie(x=data['Genre'].value_counts(), labels=None, autopct='%1.1f%%',
            startangle=90, textprops={'size': 12, 'color': 'white'},
            pctdistance=0.5, radius=1.3, colors=['#ff9999','#66b3ff'])
ax[1,5].set_title('Overall (2009 -2019)')
# Out:
# Text(0.5, 1.0, 'Overall (2009 -2019)')

# %% [markdown]
# ## Now let’s look at the top 10 bestselling authors of both fiction and non-fiction categories

# %%
data.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User_Rating  Reviews  Price  Year        Genre  \
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction
#
#    name_len
# 0        26
# 1        15
# 2        32
# 3        20
# 4        59

# %%
best_nf_authors = data.groupby(['Author', 'Genre']).agg({'Name': 'count'}).unstack()['Name', 'Non Fiction'].sort_values(ascending=False)[:11]
best_f_authors = data.groupby(['Author', 'Genre']).agg({'Name': 'count'}).unstack()['Name', 'Fiction'].sort_values(ascending=False)[:11]

# %%
best_f_authors
# Out:
# Author
# Jeff Kinney        12.0
# Rick Riordan       11.0
# Suzanne Collins    11.0
# Dr. Seuss           9.0
# J.K. Rowling        8.0
# Dav Pilkey          7.0
# Stephenie Meyer     7.0
# Eric Carle          7.0
# Stieg Larsson       6.0
# E L James           6.0
# Harper Lee          6.0
# Name: (Name, Fiction), dtype: float64

# %%
best_nf_authors
# Out:
# Author
# Gary Chapman                          11.0
# American Psychological Association    10.0
# Gallup                                 9.0
# Rob Elliott                            8.0
# Stephen R. Covey                       7.0
# Bill O'Reilly                          7.0
# Don Miguel Ruiz                        6.0
# Sarah Young                            6.0
# The College Board                      6.0
# Roger Priddy                           5.0
# Dale Carnegie                          5.0
# Name: (Name, Non Fiction), dtype: float64

# %%
with plt.style.context('seaborn-darkgrid'):
    fig, ax = plt.subplots(1, 2, figsize=(8,8))
    
    ax[0].barh(y=best_nf_authors.index, width=best_nf_authors.values,
           color='blue')
    ax[0].invert_xaxis()
    ax[0].yaxis.tick_left()
    ax[0].set_xticks(np.arange(max(best_f_authors.values)+1))
    ax[0].set_yticklabels(best_nf_authors.index, fontsize=12, fontweight='semibold')
    ax[0].set_xlabel('Number of appreances')
    ax[0].set_title('Non Fiction Authors')
    
    ax[1].barh(y=best_f_authors.index, width=best_f_authors.values,
           color='red')
    ax[1].yaxis.tick_right()
    ax[1].set_xticks(np.arange(max(best_f_authors.values)+1))
    ax[1].set_yticklabels(best_f_authors.index, fontsize=12, fontweight='semibold')
    ax[1].set_title('Fiction Authors')
    ax[1].set_xlabel('Number of appreances')
    
    fig.legend(['Non Fiction', 'Fiction'], fontsize=12)
    
plt.show()
# Out:
# <ipython-input-25-ba36e41daa95>:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0].set_yticklabels(best_nf_authors.index, fontsize=12, fontweight='semibold')
# <ipython-input-25-ba36e41daa95>:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[1].set_yticklabels(best_f_authors.index, fontsize=12, fontweight='semibold')

# %% [markdown]
# #### This is how we can analyze any data related to sales consisting of different categories.
